# %% [markdown]
# # matplotlib
#
# - 라인 플롯(line plot)
# - 스캐터 플롯(scatter plot)
# - 컨투어 플롯(contour plot)
# - 서피스 플롯(surface plot)
# - 바 차트(bar chart)
# - 히스토그램(histogram)
# - 박스 플롯(box plot)

# %% [markdown]
# ## matplotlib 및 matplotlib.pyplot 임포트하기

# %%
# %matplotlib inline

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# ## matplotlib.pyplot.plot()
#
# - plot(x,y) # plot x and y using default line style and color
# - plot(x,y, 'bo') # plot x and y using blue circle markers
# - plot(y) # plot y using x as index array 0...N-1
# - plot(y, 'r+') # ditto, but with red plusses
#
#  ** a.plot(x1,y1, 'g^', x2, y2, 'g-')

# %% [markdown]
# #### * 한글 폰트 사용하기

# %%
plt.title('한글 제목')
plt.plot([10,20,30,40], [1,4,9,16])
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 54620 (\N{HANGUL SYLLABLE HAN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44544 (\N{HANGUL SYLLABLE GEUL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51228 (\N{HANGUL SYLLABLE JE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 47785 (\N{HANGUL SYLLABLE MOG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# #### * 한글 폰트 사용하기 - 시스템 폰트 사용하기

# %%
# 시스템 폰트 경로 리스트
font_list = mpl.font_manager.findSystemFonts()
print(font_list)
# Out:
# ['C:\\WINDOWS\\Fonts\\HMFMOLD.TTF', 'C:\\Windows\\Fonts\\FRADMIT.TTF', 'C:\\Windows\\Fonts\\BRLNSDB.TTF', 'C:\\WINDOWS\\Fonts\\cambriaz.ttf', 'C:\\WINDOWS\\Fonts\\FRADMIT.TTF', 'C:\\WINDOWS\\Fonts\\H2PORL.TTF', 'C:\\WINDOWS\\Fonts\\IMPRISHA.TTF', 'C:\\Windows\\Fonts\\LHANDW.TTF', 'C:\\Windows\\Fonts\\YuGothM.ttc', 'C:\\Windows\\Fonts\\REFSAN.TTF', 'C:\\Windows\\Fonts\\NirmalaB.ttf', 'C:\\Windows\\Fonts\\LFAXDI.TTF', 'C:\\Windows\\Fonts\\H2SA1M.TTF', 'C:\\WINDOWS\\Fonts\\PERTILI.TTF', 'C:\\WINDOWS\\Fonts\\YuGothB.ttc', 'C:\\Windows\\Fonts\\HMKMRHD.TTF', 'C:\\Windows\\Fonts\\SCHLBKB.TTF', 'C:\\Windows\\Fonts\\ROCKBI.TTF', 'C:\\WINDOWS\\Fonts\\GOTHICI.TTF', 'C:\\WINDOWS\\Fonts\\PARCHM.TTF', 'C:\\WINDOWS\\Fonts\\CALISTBI.TTF', 'C:\\WINDOWS\\Fonts\\FTLTLT.TTF', 'C:\\Windows\\Fonts\\ARIALN.TTF', 'C:\\WINDOWS\\Fonts\\LFAX.TTF', 'C:\\Windows\\Fonts\\PRISTINA.TTF', 'C:\\WINDOWS\\Fonts\\STXINWEI.TTF', 'C:\\WINDOWS\\Fonts\\l_10646.ttf', 'C:\\WINDOWS\\Fonts\\GOTHIC.TTF', 'C:\\Windows\\Fonts\\HMK
# ...

# %%
# 폰트 설정하기
prop = mpl.font_manager.FontProperties(fname='원하는 폰트 경로')
plt.rcParams['font.family'] = prop.get_family()

# %% [markdown]
# #### * 한글 폰트 사용하기 - Font 설치하기
#     1. 폰트를 다운받습니다.
#      - 무료 폰트 사이트
#       a. 눈누:https://noonnu.cc/
#       b. 구글 폰트: https://fonts.google.com/
#       c. 네이버 글꼴 모음: https://hangeul.naver.com/font
#     2. 다운로드 받은 폰트를 실행하면 설치할 수 있습니다.
#       a. 리눅스에서 네이버에서 제공하는 나눔 글꼴 설치하기는 방법입니다. 해당 방법은 Colab에서도 사용 가능
#       !sudo apt install -y fonts-nanum*
#       !sudo fc-cache -fv
#       !rm ~/.cache/matplotlib -rf

# %% [markdown]
# #### * 한글 폰트 사용하기 - 외부 폰트 사용하기

# %%
# %pwd
# Out:
# 'C:\\python'

# %%
import matplotlib as mpl
# Add every font at the specified location
font_dir = ['./fonts']
for font in mpl.font_manager.findSystemFonts(fontpaths=font_dir):
    print(mpl.font_manager.FontProperties(fname=font).get_name())
    mpl.font_manager.fontManager.addfont(font)
# Out:
# Noto Sans KR
# NanumBarunGothic
# NanumBarunpenOTF
# NanumBarunpenOTF
# NanumMyeongjoOTF
# NanumMyeongjo
# NanumBarunGothicOTF
# NanumBarunGothic
# NanumBarunGothicOTF
# NanumBarunpen
# NanumMyeongjo
# NanumMyeongjoOTF
# NanumBarunGothic
# Noto Sans KR
# NanumBarunpen
# Noto Sans KR
# NanumBarunGothic
# NanumBarunGothicOTF
# NanumBarunGothicOTF
# NanumMyeongjo
# Noto Sans KR
# NanumMyeongjoOTF
# Noto Sans KR
# Noto Sans KR

# %%
# Set font family globally
mpl.rcParams['font.family'] = 'Noto Sans KR'
print(mpl.rcParams['font.family']) # parameter 변경 내용 확인 목적
# Out:
# ['Noto Sans KR']

# %%
plt.title('한글 제목')
plt.plot([10,20,30,40], [1,4,9,16])
plt.show()

# %% [markdown]
# #### 한글 폰트 사용하기 - Font scope
# 1. mpl.re('font', family='폰트명') 메서드를 통한 설정으로 전체 범위에 대해 적용하기 위 코드는 mpl.rcParams['font.fami;y'] = '폰트명'
#
# 2. fontdict keyword argument를 사용하여 세부적으로 적용

# %% [markdown]
# #### 한글 폰트 사용하기 - matplotlib.pyplot.rc()
#     -> matplotlib.pyplot.rc(group, **kwargs)

# %%
global_font = {'family': 'NanumGothic', 'size': 12, 'weight': 'bold'}

# 폰트 설정
mpl.rc('font', **global_font) # pass in the font dict as kwargs
# mpl.rc('font', 'family': 'NanumGothic', 'size': 24, 'weight': 'bold')와 같이 동작함.

# %% [markdown]
# ##### * RcParams로 설정할 수 있는 font 설정
# https://matplotlib.org/stable/api/matplotlib_configuration_api.html#matplotlib.RcParams

# %% [markdown]
# #### 한글 폰트 사용하기 - 기본 폰트 확인

# %%
plt.title('한글 제목')
plt.plot([10,20,30,40], [1,4,9,16])
plt.xlabel('엑스축 레이블')
plt.ylabel('와이축 레이블')
plt.show()

# %% [markdown]
# #### 한글 폰트 사용하기 - 개별 폰트 설정하기

# %%
import matplotlib as mpl
# Add every font at the specified location
font_dir = ['./fonts']
for font in mpl.font_manager.findSystemFonts(fontpaths=font_dir):
    print(mpl.font_manager.FontProperties(fname=font).get_name())
    mpl.font_manager.fontManager.addfont(font)
# Out:
# Noto Sans KR
# NanumBarunGothic
# NanumBarunpenOTF
# NanumBarunpenOTF
# NanumMyeongjoOTF
# NanumMyeongjo
# NanumBarunGothicOTF
# NanumBarunGothic
# NanumBarunGothicOTF
# NanumBarunpen
# NanumMyeongjo
# NanumMyeongjoOTF
# NanumBarunGothic
# Noto Sans KR
# NanumBarunpen
# Noto Sans KR
# NanumBarunGothic
# NanumBarunGothicOTF
# NanumBarunGothicOTF
# NanumMyeongjo
# Noto Sans KR
# NanumMyeongjoOTF
# Noto Sans KR
# Noto Sans KR

# %%
# Set font family globally
mpl.rcParams['font.family'] = ['NanumMyeongjo','NanumBarunGothic','NanumBarunpen']
print(mpl.rcParams['font.family']) # parameter 변경 내용 확인 목적
# Out:
# ['NanumMyeongjo', 'NanumBarunGothic', 'NanumBarunpen']

# %%
global_font = {'family': 'NanumBarunGothic', 'size': 12, 'weight': 'bold'}

# 폰트 설정
mpl.rc('font', **global_font) # pass in the font dict as kwargs
# mpl.rc('font', 'family': 'NanumGothic', 'size': 24, 'weight': 'bold')와 같이 동작함.

# %%
title_font = {"family":"NanumMyeongjo",
              "size":24,
              "color":"black"}
xlabel_font = {"family":"NanumBarunpen",
               "size":18,
               "weight":"bold",
               "color":"darkred"}
ylabel_font = {"family":"NanumBarunGothic",
               "size":12,
               "weight":"light",
               "color":"blue"}

plt.plot([10,20,30,40],[1,4,9,16])
plt.title("한글",fontdict=title_font)
plt.xlabel("엑스 축",fontdict=xlabel_font)
plt.ylabel("와이 축",fontdict=ylabel_font)
plt.show()

# %% [markdown]
# #### Unicode minus 표기법 설정
# - 음수 부호를 유니코드와 ASCII중 어떤 문자로 표기할지 설정
#   rc 메서드로 RcParams 중 axes.unicode_miuns의 값을 False로 변경하면 ASCII의 문자로 표현

# %%
# 유니코드에서 음수 부호 설정
mpl.rc('axes', unicode_minus=False)

# %% [markdown]
# ### Style 설정

# %%
plt.title('default 스타일의 plot ')
plt.plot([10,20,30,40], [1,4,9,16])
plt.show()

# %%
plt.title('"rs--" 스타일의 plot ')
plt.plot([10,20,30,40], [1,4,9,16], 'rp--')
plt.show()

# %% [markdown]
# #### Style 설정하기 - style을 설정하는 순서
#     - '색상, 마커, 선중류'

# %% [markdown]
# #### Style 설정하기 - color
# - https://matplotlib.org/2.0.2/examples/color/named_colors.html

# %% [markdown]
# #### Style 설정하기 - marker
# - .:point marker
# - ,:pixel marker
# - o:circle marker
# - v,1:triangle marker
# - ^,2:triangle_up marker
# - <,3:triangle_left marker
# - \>,4:triangle_right marker
# - _, |:hline, vline
# - *:star marker
# - p:pentagon marker
# - h:hexagon1 marker
# - H:hexagon2 marker
# - +:plus marker
# - x:x marker
# - D:diamond marker
# - d:thin_diamond marker
# https://matplotlib.org/2.0.2/api/markers_api.html?highlight=marker#module-matplotlib.markers

# %% [markdown]
# #### Style 설정하기 - linestyle
# * https://matplotlib.org/2.0.2/api/lines_api.html?highlight=line%20style#matplotlib.lines.Line2D.set_linestyle

# %% [markdown]
# #### Style 설정하기 - 기타 style
# - color: c(선 색상)
# - linewidth: lw(선 굵기)
# - linestyle: is(선 스타일)
# - marker: m(마커 종류)
# - markersize: ms(마커 크기)
# - markeredgecolor: mes(마커 선 색깔)
# - markeredgewidth: mew(마커 선 굵기)
# - markerfacecolor: mfc(마커 내부 색상)

# %%
plt.plot([10,20,30,40], [1,4,9,16], c='b',
         lw=5, ls='--', marker='o', ms=15, mec='g', mew=5, mfc='r')
plt.title('스타일 적용 예')
plt.show()

# %% [markdown]
# ### 축의 범위 설정하기
# - 플롯 그림을 보면 몇몇 점들은 그림의 범위 경계선에 있어서 잘 보이지 않는 경우가 있을 수 있음.그림의 범위를 수동으로 지정하려면 xlim(최소값, 최대값)과 ylim(최소값, 최대값)을 사용. 이는 x축, y축의 최소값과 최대값을 지정함.

# %%
plt.title('x축, y축의 범위 설정')
plt.plot([10,20,30,40], [1,4,9,16],
         c='b', lw=5, ls='--', marker='o', ms=15, mec='g', mew=5, mfc='r')
plt.xlim(0,50)
plt.ylim(-10,30)
plt.show()

# %% [markdown]
# ### 틱 설정하기
# - 플롯이나 차트에서 축상의 위치 표시 지점을 틱(tick)이라고 함.
# - 틱의 위치나 틱 라벨은 맷플롯리브가 자동으로 정해주지만 만약 수동으로 설정하고 싶다면 xticks()이나 yticks()을 사용
# - 틱 라벨 문자열에는 \$\$ 사이에 수학 문자식(Mathmatical expressions)을 넣을 수 있음.<br>
#     -> https://matplotlib.org/3.1.1/tutorials/text/mathtext.html

# %%
import numpy as np
X = np.linspace(-np.pi, np.pi, 256)
C = np.cos(X)
plt.title('x축과 y축의 tick label 설정')
plt.plot(X, C)
plt.xticks([-np.pi, -np.pi/2, 0, np.pi / 2, np.pi])
plt.yticks([-1,0,+1])
plt.show()

# %%
X = np.linspace(-np.pi, np.pi, 256)
C = np.cos(X)
plt.title('TeX, 문자열로 tick label 정의')
plt.plot(X,C)
plt.xticks([-np.pi, -np.pi/2, 0, np.pi / 2, np.pi],
          [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1,0,+1], ['Low', 'Zero', 'High'])
plt.show()

# %% [markdown]
# ### 범례(Legend)
# - 여러 개의 라인 플롯을 동시에 그리는 경우에는 각 선이 무슨 자룔를 표시하는지를 보여주기 위해 legend 명령으로 범례(legend)를 추가할 수 있음.
# - 범례의 위치는 자동으로 정해지지만 수동으로 설정하고 싶으면 loc 키워드 인수를 사용
#
# |loc|int|
# |------|---|
# |best|0|
# |upper right|1|
# |upper left|2|
# |lower left|3|
# |lower right|4|
# |right|5|
# |center left|6|
# |center right|7|
# |lower center|8|
# |upper center|9|
# |center|10|

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.title('legend를 표시한 플롯')
plt.plot(X, C, ls='--', label='cosine')
plt.plot(X, S, ls=':', label='sine')
plt.legend(loc=2) # upper left
plt.show()

# %% [markdown]
# ### x,y 축 label
# - 플롯의 x축 위치와 y축 위치에는 각각 그 데이터가 의미하는 바를 표시하기 위해 라벨(label)를 추가 가능.
# - 라벨을 붙이려면 xlabel(),ylabel() 사용

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.plot(X, C, label='cosine')
plt.xlabel('time')
plt.ylabel('amplitude')
plt.title('Cosine Plot')
plt.show()

# %% [markdown]
# ### Figure
# - Matplotlib는 data를 Figure(e.g. windows, Jupyter widgets, etc.)에 x-y좌표의 그래프로 표시(3차원은 x-y-z, 극좌표는 세타-r등). 각각의 Figure는 하나 이상의 Axes를 갖는다.
#
# - 가장 간단하게 Figure, Axes 객체를 만드는 방법은 pyplot.subplots()을 사용하는 것. Axes.plot()를 활용하여 Axes에 데이터를 그림
#
# - Figure는 전체 그림(그래프)을 의미하는 객체: Axes, 특수 Artist그룹(title, figure, legends, colorbar, etc), 그리고 심지어 중첩된 subfigures까지 포함 가능

# %%
fig, ax = plt.subplots() # Create a figure containing a single axes.
ax.plot([1,2,3,4], [1,4,2,3]); # Plot some data on the axes.

# %%
fig = plt.figure() # an empty figure with no Axes

# %%
fig, ax = plt.subplots() # a figure with a single Axes

# %%
fig, axs = plt.subplots(2,2) # a figure with a 2x2 grid of Axes

# %% [markdown]
# #### Figure - plt.plot()

# %%
np.random.seed(0)
f1 = plt.figure(figsize=(10,2))
plt.title('figure size : (10,2)')
plt.plot(np.random.randn(100))
plt.show()

# %% [markdown]
# #### Figure - plt.show()가 그래프를 그리는 방식의 차이
# - ipython의 형태인 주피터 랩에서 show() 메서드를 통해 그래프를 그려보면 별도의 Window 객체를 생성하지 않고 jupyter widget으로 결과를 보여줍니다.
# - 반대로 파이썬을 독립 실행하는 경우에는 하나의 Figure당 하나의 Window를 별도로 가집니다. 이 때 Matplotlib backends는 Figure windows에 대한 확대 및 축소 기능을 지원

# %% [markdown]
# #### Figure - Figure 객체 얻기 plt.gcf()
# - 현재 사용하고 있는 Figure 객체를 얻으려면 (다른 변수에 할당할 수도 있음.) gcf()메서드를 사용

# %%
f1 = plt.figure(1)
plt.title('현재의 Figure 객체')
plt.plot([1,2,3,4], 'ro:')

f2 = plt.gcf()
print(f1, id(f1))
print(f2, id(f2))
plt.show()
# Out:
# Figure(640x480) 2100695636816
# Figure(640x480) 2100695636816

# %% [markdown]
# #### Axes
# - Figure 객체 안에 여러 개의 플롯을 그리드(grid) 형태로 보여야하는 경우도 있음. Figure 안에 있는 각각의 플롯은 Axes라고 불리는 객체에 속함.
#
# - Figure 안에 Axes를 생성하려면 원래 subplot()을 사용하여 명시적으로 Axes객체를 얻어야 합니다. 그러나 plot()을 바로 사용해도 자동으로 Figure, Axes객체를 생성해줍니다.

# %%
ax1 = plt.subplot(2,1,1)
# 여기에서 윗부분에 그릴 플롯 명령 실행

ax2 = plt.subplot(2,1,2)
# 여기에서 아랫부분에 그릴 플롯 명령 실행

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

ax1 = plt.subplot(2,1,1)
plt.plot(x1, y1, 'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')

ax2 = plt.subplot(2,1,2)
plt.plot(x2,y2,'r.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')

# tight_layout() 명령을 실행하면 플롯 간의 간격 자동 설정
plt.tight_layout()
plt.show()

# %%
# 방법 1
np.random.seed(0)

plt.subplot(221)
plt.plot(np.random.rand(5))
plt.title('axes 1')

plt.subplot(222)
plt.plot(np.random.rand(5))
plt.title('axes 2')

plt.subplot(223)
plt.plot(np.random.rand(5))
plt.title('axes 3')

plt.subplot(224)
plt.plot(np.random.rand(5))
plt.title('axes 4')

plt.tight_layout()
plt.show()

# %%
# 방법 2
fig, axes = plt.subplots(2,2)

np.random.seed(0)
axes[0,0].plot(np.random.rand(5))
axes[0,0].set_title('axes 1')
axes[0,1].plot(np.random.rand(5))
axes[0,1].set_title('axes 2')
axes[1,0].plot(np.random.rand(5))
axes[1,0].set_title('axes 3')
axes[1,1].plot(np.random.rand(5))
axes[1,1].set_title('axes 4')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Axis
# - 하나의 Axes 객체는 두 개 이상의 Axis 객체를 가집니다. Axis 객체는 플롯의 가로축이나 세로축을 나타내는 객체
#
# - Axis 객체는 ticks(축의 표시)와 ticklabels(눈금 레이블을 지정하는 문자열)에 대한 규모의 제한을 설정
#
# - ticks의 위치는 Locator 객체에 의해 결정되며, 눈금 레이블 문자열은 Formatter 객체에 의해 형식이 지정
#
# - Locator와 Formatter 객체를 올바르게 조합하면 매우 세밀하게 tick위치와 label을 제어할 수 있음.

# %% [markdown]
# #### Axis - twinx
# - 여러가지 플롯을 하나의 객체에 표시할 때 y값의 크기가 달라서 표시하기 힘든 경우가 있을 수 있고, 이 때 twinx 명령으로 복수의 y축을 가진 플롯을 만들 수 있다.
# twinx 명령은 x축을 공유하는 새로운 Axes 객체를 만듬

# %%
fig, ax0 = plt.subplots()
ax1 = ax0.twinx()
ax0.set_title('2개의 y축을 한 figure에서 사용하기')
ax0.plot([10,5,2,9,7], 'r-', label='y0')
ax0.set_ylabel('y0')
ax0.grid(False)
ax1.plot([100,200,220,180,120],'g:',label='y1')
ax1.set_ylabel('y1')
ax1.grid(False)
ax0.set_xlabel('공유되는 x축')
plt.show()

# %% [markdown]
# ### Artist
# - 기본적으로 Figure에 보이는 모든 것들(개념적인 내용)

# %% [markdown]
# https://matplotlib.org/stable/_images/anatomy.png
# [출처 - matplotlib documentation]

# %% [markdown]
# ## 라인 플롯(line plot)

# %% [markdown]
# ### 라인 플롯(line plot) - x축의 위치(tick)
#     -> x 축의 위치를 x틱(tick)이라고 함.

# %%
plt.title('Plot')
plt.plot([1,4,9,16])
plt.show()

# %%
plt.title('x ticks')
plt.plot([10,20,30,40], [1,4,9,16])
plt.show()

# %% [markdown]
# ### 라인 플롯(line plot) - title()
#     -> 플롯의 제목을 의미

# %%
plt.title('Plot')
plt.plot([1,4,9,16])
plt.show()

# %%
plt.title('x ticks')
plt.plot([10,20,30,40], [1,4,9,16])
plt.show()

# %% [markdown]
# ### 라인 플롯(line plot)
#     -> show()는 플롯을 그림으로 표시
#   * 주피터 랩과 같이 ipython(Interactive Python) 환경에서 실행할 경우 모든 수치를 표시하고 ipyhton 프롬프트로 돌아감.

# %% [markdown]
# ### 여러 개의 선 그리기

# %%
t = np.arange(0., 5., 0.2)
plt.title('라인 플롯에서 여러개의 선 그리기')
plt.plot(t, t, 'r--', t, 0.5 * t**2, 'bs:', t, 0.2 * t**3, 'g^-')
plt.show()

# %%
plt.title('복수의 plot 명령을 한 그림에서 표현')
style1 = {'c':'b', 'lw':5, 'ls':'--', 'marker':'o', 'ms':15, 'mec':'g', 'mew':5, 'mfc':'r'}
style2 = {'c':'k', 'lw':3, 'ls':':', 'marker':'s', 'ms':10, 'mec':'m', 'mew':5, 'mfc':'c'}

plt.plot([1,4,9,16], **style1)
plt.plot([9,16,4,1], **style2)

plt.show()

# %%
# 연습문제
#- title: 섭씨 온도와 화씨 온도
#- xlabel: 화씨 온도
#- ylabel: 섭씨 온도
#- x 값은 화씨로 32이상~100미만의 정수, y 값은 섭씨로 ℃ = (℉ − 32) × 5/9 를 
#통해 구합니다

# %%
x = range(32,100)
y = [(i - 32) * 5/9 for i in x]

# %%
# 연습 문제
x = range(32,100)
y = [(i - 32) * 5/9 for i in x] 
plt.title('섭씨 온도와 화씨 온도')
plt.plot(x,y,c='r', ls='-.')
plt.xlabel('화씨 온도')
plt.ylabel('섭씨 온도')
plt.show()

# %% [markdown]
# ## 바 차트
# - x 데이터가 카테고리 값(순서형)인 경우에는 bar명령과 barh명령으로 바 차트(bar chart)를 시각화 가능.
# - 가로 방향으로 바 차트를 그리려면 barh 명령 사용
#     * 바 차트 작성시 주의점은 첫번째 인수인 left가 x축에서 바(bar)의 왼쪽 변의 위치를 나타낸다는 점

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

y = [2,3,1]
x = ['가', '나', '다']

plt.title('Bar Chart')
plt.bar(x,y)
plt.xlabel('가나다')
plt.ylabel('빈도 수')
plt.show()

# %% [markdown]
# #### 바 차트 - color
# - 적용하고 싶은 색상을 데이터 순으로 리스트로 생성
# - 생성한 리스트를 bar()의 color 키워드 인수로 전달

# %%
x = ['가', '나', '다']
y = [2,3,1]
colors = ['red', 'green', 'blue']

plt.title('Bar Chart')
plt.bar(x, y, color=colors)
plt.xlabel('가나다')
plt.ylabel('빈도 수')
plt.show()

# %% [markdown]
# #### 바 차트 - xerr 인수 or yerr 인수 + alpha(투명도)
# - xerr 인수 or yerr 인수: 에러 바를 추가함.
# - alpha: 투명도 지정(0-완전 투명, 1-완전 불투명)

# %%
np.random.seed(0)

people = ['몽룡', '춘향', '방자', '향단']
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

plt.title('Barh chart')
plt.barh(people, performance, xerr=error, alpha=0.4)
plt.xlabel('x 라벨')
plt.show()

# %%
import seaborn as sns

# %%
titanic = sns.load_dataset('titanic')
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic['alive'].value_counts()
# Out:
# no     549
# yes    342
# Name: alive, dtype: int64

# %%
np.array(titanic['alive'].value_counts())
# Out:
# array([549, 342], dtype=int64)

# %%
# 연습문제
plt.title('타이타닉호 생존 여부')
x = ['사망자', '생존자']
y = np.array(titanic['alive'].value_counts())
colors = ['red', 'green']

plt.barh(x,y,color=colors)
plt.xlabel('인원수')
plt.show()

# %%
# 풀이
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

titanic = sns.load_dataset('titanic')
bar_chart = titanic['alive'].value_counts()
bar_chart.rename({'no':'사망자', 'yes':'생존자'}, inplace=True)
bar_chart
# Out:
# 사망자    549
# 생존자    342
# Name: alive, dtype: int64

# %%
alive = bar_chart.index
value = bar_chart.values
bar_colors = ['red', 'green']

plt.title('타이타닉호 생존 여부')
plt.barh(alive, value, color=bar_colors)
plt.xlabel('인원 수')
plt.show()

# %% [markdown]
# ## 파이 차트
# -> 카테고리 별 값의 상대적인 비교를 해야 할 때는 pie 명령으로 파이 차트(pie chart)로 그릴 수 있다.

# %%
labels = ['월세','전세','자가','기타']
sizes = [15,30,45,10]
colors = ['yellowgreen','gold','lightskyblue','lightcoral']
explode = (0,0,0.1,0)
plt.title("Pie Chart")
plt.pie(sizes,explode=explode,labels=labels,colors=colors,
       autopct='%1.1f%%',shadow=True,startangle=90)
plt.axis("equal") # 원의 형태를 유지
plt.show()

# %%
# 연습 문제
bins = [0,20,30,50,70,100]
labels = ['미성년자', '청년', '장년', '중년', '노년']
explode = (0.1, 0, 0, 0, 0)
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral', 'orange']

# %%
sizes = titanic[titanic['age'].notnull()]['age']
sizes_group = pd.cut(sizes,bins,labels=labels)
sizes_group_percent = sizes_group.value_counts(True)
sizes_group_percent
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21496\75020207.py in <module>
#       1 sizes = titanic[titanic['age'].notnull()]['age']
# ----> 2 sizes_group = pd.cut(sizes,bins,labels=labels)
#       3 sizes_group_percent = sizes_group.value_counts(True)
#       4 sizes_group_percent
#
# NameError: name 'pd' is not defined

# %%
plt.title("Titanic age grouping")
plt.pie(sizes_group_percent,explode=explode,labels=sizes_group_percent.index,colors=colors,
       autopct='%1.1f%%',shadow=True,startangle=90)
plt.axis("equal")
plt.show()

# %% [markdown]
# ## 히스토그램
# - 히스토그램을 그리기 위한 hist 명령도 있음.
# - hist 명령은 bins 인수로 데이터를 집계할 구간 정보를 받는다.
# - 반환값으로 데이터 집계 결과를 반환

# %%
np.random.seed(0)
x = np.random.randn(1000)
plt.title('Histogram')
arrays, bins, patches = plt.hist(x, bins=10)
plt.show()

# %%
arrays

# %%
bins

# %% [markdown]
# ## 스캐터 플롯
# - 2차원 데이터, 즉 두 개의 실수 데이터 집합의 상관관계를 살펴보려면 scatter명령으로 스캐터 플롯을 그림. 스캐터 플롯의 점 하나의 위치는 데이터 하나의 x,y값임.

# %%
np.random.seed(0)
X = np.random.normal(0,1,100)
Y = np.random.normal(0,1,100)
plt.title('Scatter Plot')
plt.scatter(X,Y)
plt.show()

# %% [markdown]
# ### 스캐터 플롯 - 버블 차트
# - 데이터가 2차원이 아니라 3차원 혹은 4차원인 경우에는 점 하나의 크기 혹은 색깔을 이용하여 다른 데이터 값을 나타냄. 이를 버블 차트라고 함.<br>
# (크기는 s 인수로 색깔은 c인수로 지정)

# %%
N = 30
np.random.seed(0)
x = np.random.rand(N)
y1 = np.random.rand(N)
y2 = np.random.rand(N)
y3 = np.pi * (15 * np.random.rand(N)) ** 2
plt.title('Bubble Chart')
plt.scatter(x, y1, c=y2, s=y3)
plt.show()

# %% [markdown]
# ## imshow
# - 화상(image) 데이터처럼 행과 열을 가진 행렬 형태의 2차원 데이터는 imshow 명령을 써서 2차원 자료의 크기를 색깔로 표시하는 것<br>
#
# - 데이터 수치를 색으로 바꾸는 함수는 칼라맵(color map)이라고 함. => 칼라맵은 cmap 인수로 지정

# %%
from sklearn.datasets import load_digits
digits = load_digits()
X = digits.images[0]
X

# %%
plt.title('mnist digits; 0')
plt.imshow(X, interpolation='nearest', cmap=plt.cm.bone_r)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.subplots_adjust(left=0.35, right=0.65, bottom=0.35, top=0.65)
plt.show()

# %%
dir(plt.cm)[:10]

# %%
fig, axes = plt.subplots(1,4,figsize=(12,3),
                         subplot_kw={'xticks': [], 'yticks': []})
axes[0].set_title('plt.cm.Blues')
axes[0].imshow(X, interpolation='nearest', cmap=plt.cm.Blues)
axes[1].set_title('plt.cm.Blues_r')
axes[1].imshow(X, interpolation='nearest', cmap=plt.cm.Blues_r)
axes[2].set_title('plt.cm.BrBG')
axes[2].imshow(X, interpolation='nearest', cmap='BrBG')
axes[3].set_title('plt.cm.BrBG_r')
axes[3].imshow(X, interpolation='nearest', cmap='BrBG_r')
plt.show()

# %%
methods = [None, 'none', 'nearest', 'bilinear', 'bicubic', 'spline16',
           'spline36', 'hanning', 'hamming', 'hermite', 'kaiser', 'quadric',
           'catrom', 'gaussian', 'bessel', 'mitchell', 'sinc', 'lanczos'
          ]
fig, axes = plt.subplots(3, 6, figsize=(12,6),
                         subplot_kw={'xticks': [], 'yticks': []})
for ax, interp_method in zip(axes.flat, methods):
    ax.imshow(X, cmap=plt.cm.bone_r, interpolation=interp_method)
    ax.set_title(interp_method)
plt.show()

# %% [markdown]
# ### 컨투어 플롯
# - 입력 변수가 x, y 두 개이고 출력 변수가 z 하나인 경우에는 3차원 자료가 된다. 3차원  자료를 시각화하는 방법은 명암이 아닌 등고선(contour)을 사용하는 방법이다. contour  혹은 contourf 명령을 사용한다. contour는 등고선만 표시하고 contourf는 색깔로 표시한다. 입력 변수 x, y는 그대로 사용할 수 없고 meshgrid 명령으로 그리드 포인트 행렬을 만들어야 한다.

# %%
def f(x,y):
    return (1 - x / 2 + x ** 5 + y ** 3) * np.exp(-x ** 2 -y ** 2)
n = 256
x = np.linspace(-3,3,n)
y = np.linspace(-3,3,n)
xx,yy = np.meshgrid(x,y)
zz = f(xx,yy)
plt.title("Contour plota")
plt.contourf(xx,yy,zz,alpha=.75, cmap = "jet")
plt.contour(xx,yy,zz,colors="black")
plt.show()

# %% [markdown]
# ### 3D 서비스 플롯
# - 3차원 플롯은 등고선 플롯과 달리 Axes3D라는 3차원 전용 axes를 생성하여 입체적으로  표시한다.
# plot_wireframe(), plot_surface() 명령을 사용한다

# %%
from mpl_toolkits.mplot3d import Axes3D
x = np.arange(-4,4,0.25)
y = np.arange(-4,4,0.25)
xx,yy = np.meshgrid(x,y)
rr = np.sqrt(xx**2 + yy**2)
zz = np.sin(rr)
fig = plt.figure()
ax = Axes3D(fig)
ax.set_title("3D Surface Plot")
ax.plot_surface(xx,yy,zz,rstride=1,cstride=1,cmap='hot')
plt.show()
