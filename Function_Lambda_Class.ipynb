# %% [markdown]
# # 1. 함수(Function)
#
# -> 프로그래밍에서 함수(function)는 독립적으로 설계된 프로그램 코드의 집합
#    함수를 사용하면 반복적인 코드의 양을 줄여 유지보수성을 높여줍니다.
#
# -> 반복 사용되는 코드를 용도에 맞게 함수 바디에 모아두고 재사용 가능하도록 호출 가능하게 만든 것
#
#     - 코드의 중복을 줄일 수 있어서 유지보수에 유리
#         -> 코드를 목적에 맞게 사용
#         -> 중복에서 오는 실수를 줄임
#         -> 재사용 가능

# %%
# ![image.png](attachment:2934b662-5b1b-48d7-b1f8-d5aafc85e4d9.png)

# %%
# ![image.png](attachment:fa7e54f5-e34b-4483-82b5-594661b210a1.png)

# %%
# ![image.png](attachment:3e8e549a-348e-4ba2-9a0f-9f29a0116e6b.png)

# %%
# ![image.png](attachment:2af0b5c9-8bc4-4ee7-af84-67b1a5a08223.png)

# %% [markdown]
# ## 1) 함수(Function) vs 메서드(Method)
#
# -> 함수는 클래스에 포함되지 않은 채로 사용<br>
#     * 함수명((인수1), (인수2), ...)
#
# -> 메서드는 클래스에 포함되어 객체를 호출<br>
#     * 객체.메서드명((인수1), (인수2), ...)

# %% [markdown]
# ## 2) 함수의 정의(<u>def</u>ine)
#
# 함수는 미리 정의해둔 정의절을 실행해야 호출가능
#
#     * return -> keyword 만나면 함수를 빠져나갑니다.

# %%
def 함수_이름(위치_인자, 위치_인자2, *가변_위치, 키워드_인자, 키워드_인자2, **가변_키워드):
    """
    Doc String을 적는 곳입니다.   ## Doc string - 설명 달기
    
    작성자: 이기수
    작성일자: 2020.02.03
    
    """
    
    함수의 바디
    함수의 바디
    
    return 반환값

# %%
def print_ten():
    """print("hello")를 열번 출력합니다."""
    for _ in range(10):
        print("hello")

# %%
def print_ten_2(some_str):
    """print("hello")를 열번 출력합니다."""
    for _ in range(10):
        print(some_str)

# %%
print_ten()
# Out:
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello
# hello

# %%
print_ten_2(문자열)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17460\1447231974.py in <module>
# ----> 1 print_ten_2(문자열)
#
# NameError: name '문자열' is not defined

# %%
# 해당 함수의 Doc String 확인
print(print_ten.__doc__)
# Out:
# print("hello")를 열번 출력합니다.

# %%
print(print.__doc__)
# Out:
# print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
# Prints the values to a stream, or to sys.stdout by default.
# Optional keyword arguments:
# file:  a file-like object (stream); defaults to the current sys.stdout.
# sep:   string inserted between values, default a space.
# end:   string appended after the last value, default a newline.
# flush: whether to forcibly flush the stream.

# %% [markdown]
# ## 3) 함수의 정의(define) - 인자(parameter)
#
# -> 함수(또는 메서드) 정의에서 함수가 받을 수 있는 변수(함수인자 혹은 매개변수)<br>
# -> 함수 정의절에서 소괄호 안에 정의됩니다.<br>
#
# * 위치-키워드(positional or keyword): 위치로 혹은 키워드로 전달될 수 있는 인자를 말합니다. 매개변수의 기본 형태입니다.<br>
# * 위치 전용(positional-only): / 문자를 기준으로 좌측에 위치한 인자를 말합니다.<br>
# * 키워드 전용(keyword-only): * 문자를 기준으로 우측에 위치한 인자를 말합니다.<br>
# * 가변 위치(var positional): 위치 매개변수 외에 추가적인 위치 매개변수를 개수에 상관없이 받을 수 있습니다. 변수명 앞에 *를 앞에 하나 붙여 표기합니다.<br>
# * 가변 키워드(var keyword): 키워드 매개변수 외에 추가적인 키워드 매개변수를 개수에 상관없이 받을 수 있습니다. 변수명 앞에 **를 두개 붙여 표기합니다.
#
# ex) dict_a = dict(key='value', key2='value2')

# %% [markdown]
# ### Arguments? Parameter? 같은 것 아닌가?
# -> 다르다.<br>
#     * Parameters는 함수 정의절에 사용하는 이름<br>
#     * Arguments는 함수 호출할 때 함수에 전달하는 실제 값

# %%
def greeting(name,age):  # Parameter - 규격(값x)
    print(f'{name} 씨 안녕하세요. 약 {age * 365.25} 일 되었습니다.')

# %%
greeting("파이썬", 32) # Argument - 호출할 때의
# Out:
# 파이썬 씨 안녕하세요. 약 11688.0 일 되었습니다.

# %% [markdown]
# ## 4) 함수의 정의(define) - 위치-키워드 인자(positional-or-keyword parameters)
#     -> 기본 값이 없는 경우는 인수(arguments) 전달이 필수 입니다.

# %%
def greeting(name, age):  #기본 값(default)가 설정되어 있지 않네요!
    print(f'{name} 씨 안녕하세요. 약 {age * 365.25}일 되었습니다.')

# %%
greeting('파이썬', 32)
# Out:
# 파이썬 씨 안녕하세요. 약 11688.0일 되었습니다.

# %%
greeting()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17460\3595202211.py in <module>
# ----> 1 greeting()
#
# TypeError: greeting() missing 2 required positional arguments: 'name' and 'age'

# %%
# * 단, 타입에 민감하게 동작하는 함수라면 값을 처리할 수 없을 수 있다.
greeting(32, "파이썬")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17460\208747169.py in <module>
#       1 # * 단, 타입에 민감하게 동작하는 함수라면 값을 처리할 수 없을 수 있다.
# ----> 2 greeting(32, "파이썬")
#
# ~\AppData\Local\Temp\ipykernel_17460\1249234427.py in greeting(name, age)
#       1 def greeting(name, age):
# ----> 2     print(f'{name} 씨 안녕하세요. 약 {age * 365.25}일 되었습니다.')
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
# 키워드 인수 만으로 호출 가능 - 딕셔너리와 같은 맥락,원리 => 그래서 순서 중요치 않음
greeting(age=32, name="파이썬")
# Out:
# 파이썬 씨 안녕하세요. 약 11688.0일 되었습니다.

# %% [markdown]
# ## 5) 함수의 호출 - 위치 인수와 키워드 인수
#
# -> 소괄호(())안에 위치 인수(positional arguments)를 먼저 작성하고 키워드 인수(keyword arguments)를 나중에 작성<br>
#     => 위치 인수는 순서에 영향을 받지만 키워드 인수는 순서에 상관없이 작성 가능

# %%
greeting(name="파이썬",32)
# Out:
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_17460\1495660395.py", line 1
#     greeting(name="파이썬",32)
#                           ^
# SyntaxError: positional argument follows keyword argument

# %%
# ![image.png](attachment:0ea58978-7f9e-4370-a843-bca7b4681ab9.png)

# %%
# 기본 값을 갖는 default parameter는 기본 값을 갖지 않는 non-default parameter보다 뒤에 작성
def greeting(name="defalut",age):
    print(f'{name} 씨 안녕하세요. 약 {age * 365.25} 일 되었습니다.')
# Out:
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_17460\3808629012.py", line 2
#     def greeting(name="defalut",age):
#                                    ^
# SyntaxError: non-default argument follows default argument

# %% [markdown]
# ![image.png](attachment:580752fe-056e-4c51-b22f-9ba094fc46b2.png)

# %% [markdown]
# ## 6) 함수의 정의 - 위치 전용 인자(positional-only parameters)
#
# -> 오직 위치 인수(positional arguments)만 값의 전달이 가능.<br>
# -> 위치 전용 인자를 선언하는 방법은 슬래시(/)를 인자 값으로 넣고 좌측 부분에 위치 전용 인자를 선언

# %%
def posonly(posonly, /):
    print(posonly)

# %%
posonly("값만 입력해야 합니다.")
# Out:
# 값만 입력해야 합니다.

# %%
# 키워드 인수를 전달한 경우
posonly(posonly="키워드 인수로 전달하면 오류 발생!")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17460\1596398235.py in <module>
#       1 # 키워드 인수를 전달한 경우
# ----> 2 posonly(posonly="키워드 인수로 전달하면 오류 발생!")
#
# TypeError: posonly() got some positional-only arguments passed as keyword arguments: 'posonly'

# %% [markdown]
# ## 7) 함수의 정의 - 키워드 전용 인자(keyword-only parameters)
#
# -> 기본값을 가질 수 있음(이때 기본값을 갖는 인자에 상응하는 인수(arguments)는 생략 가능)<br>
# -> 키워드 전용 인자(keyword only parameter)는 오직 위치 인수(keyword arguments)만 값의 전달이 가능합니다. 키워드 전용 인자를 선언하는 방법은 애스터리스크(*)를 인자 값으로 넣고 우측 부분에 키워드 전용 인자를 선언

# %%
def keyonly(*, keyonly="defalut"):
    print(keyonly)

# %%
keyonly()
# Out:
# defalut

# %%
keyonly(keyonly="키워드로만 입력해야 합니다.")
# Out:
# 키워드로만 입력해야 합니다.

# %%
# 위치 인수를 전달한 경우
keyonly("키워드로만 입력해야 합니다.")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17460\3050613226.py in <module>
#       1 # 위치 인수를 전달한 경우
# ----> 2 keyonly("키워드로만 입력해야 합니다.")
#
# TypeError: keyonly() takes 0 positional arguments but 1 was given

# %% [markdown]
# ## 8) 함수의 정의 - 가변-위치 인자(var-positional parameters)
#
# -> <u>명시된 인자 외에</u> 추가적으로 위치 인수를 개수에 상관없이 유연하게 전달 받을수 있음. 가변 변수로 사용할 변수명 앞에 '*'를 앞에 하나 붙여 표기

# %%
def var_positional(*args):
    print(type(args))
    return sum([_ for _ in args])

# %%
print(var_positional(1,2,3,4,5))
# Out:
# <class 'tuple'>
# 15

# %%
# 해당 변수에 값을 전달하는 인수가 아예 없어도 함수가 동하는데 문제없도록 함수 바디를 작성 필요
def var_positional(*args):
    print(type(args))
    return sum([_ for _ in args])

# %%
print(var_positional())
# Out:
# <class 'tuple'>
# 0

# %% [markdown]
# ## 9) 함수의 정의 - 가변-키워드 인자(var-keyword parameters)
#
# -> 명시된 인자 외에 추가적으로 키워드 인수를 개수에 상관없이 유연하게 전달 받을 수 있음. 가변 변수로 사용할 변수명 앞에 '*'를 앞에 두개 붙여 표기

# %%
def var_keyword(**kwargs):
    print(type(kwargs))
    return kwargs

# %%
print(var_keyword(key="value", key2="value2"))
# Out:
# <class 'dict'>
# {'key': 'value', 'key2': 'value2'}

# %%
# 해당 변수에 값을 전달하는 인수가 아예 없어도 함수가 동작하는데 문제 없도록 함수 바디를 작성
def var_keyword(**kwargs):
    print(type(kwargs))
    return kwargs

# %%
print(var_keyword())
# Out:
# <class 'dict'>
# {}

# %%
# 연습 문제

def plus_ten(num):
    result = int(num) + 10
    return result

# %%
print("반환 값:", plus_ten(70))

# %%
# 연습 문제

def to_celsius(fahrenheit):
    """ 화씨 온도를 입력하면 섭씨 온도로 변경해주는 계산기"""
    return (float(fahrenheit) - 32) * 5/9

print('반환 값:', to_celsius(70))
# Out:
# 반환 값: 21.11111111111111

# %%
print(to_celsius.__doc__)
# Out:
#  화씨 온도를 입력하면 섭씨 온도로 변경해주는 계산기

# %%
# 연습 문제

def odd_even(number):
        """number가 짝수면 "짝수", 홀수면 "홀수" 반환"""
        if type(number) is int:
            return
        else:
            if number % 2 == 0:
                even_pt = "짝수"
                return even_pt
            elif number % 2 == 1:
                odd_pt = "홀수"
                return odd_pt

# %%
print(odd_even.__doc__)
print(odd_even(10))
print(odd_even(9))
print(odd_even("가"))
# Out:
# number가 짝수면 "짝수", 홀수면 "홀수" 반환
# 짝수
# 홀수
# None

# %%
# 연습 문제

def odd_even(number):
        """number가 짝수면 "짝수", 홀수면 "홀수" 반환"""
        if type(number) != int:
            return
        else:
            if number % 2 == 0:
                return "짝수"
            elif number % 2 == 1:
                return "홀수"

# %%
print(odd_even.__doc__)
print(odd_even(10))
print(odd_even(9))
print(odd_even("가"))
# Out:
# number가 짝수면 "짝수", 홀수면 "홀수" 반환
# 짝수
# 홀수
# None

# %%
# 풀이
def odd_even(number):
    """number가 짝수면 "짝수", 홀수면 "홀수" 반환"""
    if type(number) is int and number > 0:
        return "짝수" * (number % 2 == 0) or "홀수" # 논리 연산자 (True = 1, False = 0) 이용
    else:
        return

# %%
# ![image.png](attachment:f1f15bc6-ae50-4032-ad94-4356b7a76be0.png)
-> isdecimal # 10진법으로 변경 가능?

# %%
number = input("숫자를 입력하세요")
# Out:
# 숫자를 입력하세요 10.1

# %%
type(number)
# Out:
# str

# %%
number
# Out:
# '10.1'

# %%
number.isdecimal()
# Out:
# False

# %%
def to_int(number):
    if number.isdecimal():
        return int(number)
    return

# %%
print(to_int(number))
# Out:
# None

# %%
# 연습 문제

def check_leap_year(ck_year):
    if ck_year % 100 == 0 and ck_year % 400 != 0:
        return "평년"
    elif ck_year % 4 == 0:
        return "윤년"
    else:
        return "평년"

# %%
check_leap_year(1900)
# Out:
# '평년'

# %%
# 연습 문제

def days(month):
    if int(month) in (4,6,9,11):
        return 30
    elif int(month) == 2:
        return 28
    else:
        return 31

# %%
print(days(11))
print(days(2))
print(days(1))
# Out:
# 30
# 28
# 31

# %%
# 평년 - 31/30/28
# 윤년 - 31/30/29
#

# %%
# 연습 문제

def days(ck_year, month):
    if ck_year % 4 == 0 and (ck_year % 100 != 0 or ck_year % 400 == 0) and month == 2:
        return 29
    else:
        if int(month) in (4,6,9,11):
            return 30
        elif int(month) == 2:
            return 28
        else:
            return 31

# %%
# 풀이
def days(y, m):
    if m in (1,3,5,7,8,10,12):
        return 31
    elif m in (4,6,9,11):
        return 30
    elif 
    
    else:
# Out:
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_17460\1522386566.py", line 7
#     elif
#          ^
# SyntaxError: invalid syntax

# %%
days(1900,11)
# Out:
# 30

# %%
days(2004,10)
# Out:
# 31

# %%
days(1900,2)
# Out:
# 28

# %%
days(2000,2)
# Out:
# 29

# %% [markdown]
# ## 10) 변수의 범위(variable scope) - 전역 변수(global variable)
#
# -> 제일 바깥 영역(들여쓰기 없이 쓴 영역)인 전역 범위(global scope)에서 변수를 선언하고 활용. 전역 범위에서 선언했기 때문에 그 변수를 스크립트 전체에서 접근할 수 있었는데, 그 변수를 전역 변수라고 함.

# %%
global_variable = "This is global world." # 전역 변수 선언

print(f'global_variable in global scope => {global_variable}')
print(hex(id(global_variable)))

def local_world():
    print(f'global_variable in local_word => {global_variable}')
    print(hex(id(global_variable)))

local_world()
# Out:
# global_variable in global scope => This is global world.
# 0x1dfdebfdf80
# global_variable in local_word => This is global world.
# 0x1dfdebfdf80

# %% [markdown]
# ## 11) 변수의 범위(variable scope) - 지역 변수(local variable)
#
# -> 함수 바디(local scope)에서 선언된 변수 - 바깥 접근 x

# %%
def my_little_world():
    my_variable = "This is my little world."

print(my_variable) # 에러 발생
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17460\877465239.py in <module>
#       2     my_variable = "This is my little world."
#       3
# ----> 4 print(my_variable) # 에러 발생
#
# NameError: name 'my_variable' is not defined

# %% [markdown]
# ## 12) 변수의 범위(variable scope) - 지역 범위에서 전역 변수 할당하기

# %%
important_is_an_unbroken_heart = "중요한 것은 꺾이지 않는 마음"

def trials_and_tribulations():
    important_is_an_unbroken_heart = "흔들흔들"

trials_and_tribulations()
print(important_is_an_unbroken_heart)
# Out:
# 중요한 것은 꺾이지 않는 마음

# %%
global_varialbe = "변경이 됩니까?"

def heartbreaker():
    global global_variable # global 키워드를 활용하여 전역변수를 사용하겠다고 설정
    global_variable = "global 키워드 활용해서 변경 완료"

heartbreaker()
print(global_variable)
# Out:
# global 키워드 활용해서 변경 완료

# %% [markdown]
# ## 13) 함수 바디에 함수를 중첩해서 만들기

# %%
def level1():
    message = "This is level 1."
    def level2():
        print(message)
    level2()

# %%
level1()
# Out:
# This is level 1.

# %% [markdown]
# ## 14) 안쪽 함수에서 바깥쪽 함수의 변수 변경

# %%
def level1():
    message = "This is level 1."
    def level2():
        message = "Level2 is better than level1."
    level2()
    print(message)

# %%
level1()
# Out:
# This is level 1.

# %% [markdown]
# ## 15) 안쪽 함수에서 바깥쪽 함수의 변수 변경해보기

# %%
def level1():
    message = "This is level 1."
    def level2():
        nonlocal message 
        message = "Level2 is better than level1."
    level2()
    print(message)

# %%
level1()
# Out:
# Level2 is better than level1.

# %% [markdown]
# ### * global, nonlocal 특징과 권고사항
# -> global 키워드는 함수의 중첩된 정도와 상관없이 전역 범위의 변수를 매칭<br>
# -> 중첩된 함수마다 같은 이름의 변수가 있다면 nonlocal 키워드는 제일 가까운 바깥 변수를 매칭<br>
# -> 가급적이면 함수마다 이름이 같은 변수를 사용하기보단 다른 변수명을 사용하는게 좋다

# %% [markdown]
# ### * 변수 범위 정리
# - 함수 안에서 선언한 변수는 함수를 호출해 실행하는 동안만 사용
# - 범위마다 같은 이름의 변수를 사용해도 각각 독립적으로 동작
# - 지역 변수(local variable)를 저장하는 이름 공간: 지역 영역(local scope)
# - 전역 변수(global variable)를 저장하는 이름 공간: 전역 영역(global scope)
# - 파이썬 자체에서 정의한 이름 공간을 내장 영역(built-in scope)
# - 함수에서 변수를 호출하면 지역 영역 -> 전역 영역 -> 내장 영역 순으로 해당하는 변수를 확인

# %% [markdown]
# # 2. 람다(Lambda)
# -> 호출될 때 값이 구해지는 하나의 표현식. 이름이 없는 인라인 <u>함수</u>
#
# lambda[parameters(매개변수를 지정)]:exression(arguments(변환값으로 사용할 식))<br>
#     => lambda 표현식
#
# *일반 함수 정의절* def func_name(parameter):
#     return expression

# %%
(lambda x: x+10)(10)
# Out:
# 20

# %%
# variable = lambda[parameters]:expression - variable(argument)
twice = lambda x: x*2
print(twice(10))
# Out:
# 20

# %%
# expression  부분은 변수 없이 식 한줄로 표현 가능(인라인)
# 표현식 안에 새 변수를 만들 수 x
(lambda x: y=10; x+y)(1)
# Out:
#   File "C:\Users\user\AppData\Local\Temp\ipykernel_17460\1727540298.py", line 1
#     (lambda x: y=10; x+y)(1)
#                 ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 1) 조건 표현식(Conditional Expression), inline if else
#
# True 일때 값/ if 조건식/ else/ False일때 값

# %%
score = 90
'A' if 90<score<=100 else 'B' if 80<score else 'C'
# Out:
# 'B'

# %% [markdown]
# ## 2) 람다(Lambda) feat.map()
#
# map(lambda parameter1, parameter2, ...:expression, iterable1,iterable2)

# %%
a = [_ for _ in range(1,6)]
b = [_ for _ in range(2,11,2)]
print(list(map(lambda x, y: x * y, a, b)))
# Out:
# [2, 8, 18, 32, 50]

# %% [markdown]
# ## 3) 람다(Lambda) feat. filter()
#
# map(lambda parameter: expression, iterable)
# -> filter의 첫 인수로 들어가는 함수의 반환값이 True일 때만 해당 요소를 가져온다.

# %%
a = [3, 2, 8, 22, 10, 7, 0, 11, 9, 9]
list(filter(lambda x: x % 3 == 0 and 0 < x < 10, a))
# Out:
# [3, 9, 9]

# %% [markdown]
# # 3. 클래스(Class)
#
# -> 사용자 정의 객체를 만들기 위한 주형(설계)
#
# -> 보통 클래스의 인스턴스를 대상으로 연산하는 메서드 정의를 포함하고 있다.
#
# class ClassName:           #클래스명으로 주로 PascalCase(UpperCamelCase)를 씀<br>
#     def method_name(self):<br>
#         method_body
#
#     class_body

# %%
number = int(10)
print(type(number))

num_list = list(range(10))
print(type(num_list))

num_dict = dict(key="value1", key2="value2")
print(type(num_dict))
# Out:
# <class 'int'>
# <class 'list'>
# <class 'dict'>

# %% [markdown]
# ## 1) 객체? 인스턴스?
# - 객체를 언급할 땐 단어 하나만 활용 -> 단지 '객체'라고 표현
# - 인스턴스는 특정 클래스로부터 만들어진 실체
#
# instance_variable = ClassName()

# %% [markdown]
# ## 2) 메서드(Method)
# - 클래스 바디 안에서 정의되는 함수
# -> 클래스의 인스턴스의 어트리뷰트(attribute)로서 호출되면, 그 메서드는 첫번째 인자로 인스턴스 객체(self)를 받는다.
#
# class ClassName():

# %% [markdown]
# ## 3) 클래스 속성(Attribute)

# %%
class Student:
    # 생성자: 객체가 최초 생성될 때
    # 단 한번에 실행되는 메서드
    def __init__(self):
        # self라는 것은 내 자신의 인스턴스 
        self.name = "홍길동"

# %%
# Student 클래스로부터 객체를 하나 생성될때 단 한번 실행되는 메서드
s1 = Student()

# %%
type(s1)
# Out:
# __main__.Student

# %%
type(s1.name)
# Out:
# str

# %%
s1.name = "이몽룡"

# %%
s1.name
# Out:
# '이몽룡'

# %%
class Person:
    def __init__(self):
        self.hello = "안녕하세요."
    
    def greeting(self):
        print(self.hello)

james = Person()
james.greeting()

# %%
class ClassName:
    def __init__(self):
        self.속성 = 값

# %% [markdown]
# __init__메서드는 james = Person()처럼 클래스에 소괄호(())를 붙여서 인스턴스를 만들 때 호출되는 특별한 메서드(special method, magic method)입니다.
#
# __init__은 initialize의 줄임말로 인스턴스(객체)를 초기화(메모리에 공간을 할당하고 값을 부여함)
#
# 밑줄 두개(__ double under,던더)가 양 옆으로 붙어있는 메서드는 파이썬이 자동으로 호출하는 메서드. 스페셜 메서드 혹은 매직 메스드라고 부릅니다. 던더 메서드로 불리기도 합니다. 파이썬의 여러 가지 기능을 사용할 때 이 던더 메서드를 구현하는 식으로 사용

# %% [markdown]
# 속성은 __init__메서드에서 만든다는 점과 self에 마침표(.)를 붙여 속성명을 붙이고 값을 할당한다
#
# 클래스 바디에서도 속성을 접근할 때 self.속성과 같이 self에 마침표를 찍고 사용

# %% [markdown]
# 인스턴스 자기 자신을 의미
#
# 인스턴스가 생성될 때 self.hello = '안녕하세요.'처럼 자기 자신에 속성을 추가하여 사용
#
# __init__의 매개변수 self에 들어가는 값은 Person() 인스턴스라고 함.
# self 완성된 후에는 변수인 james에 할당
#
# 이후 메서드를 호출하면 현재 인스턴스가 자동으로 매개변수 self에 들어옴. 그래서 greeting 메서드에서 print(self.hello)처럼 속성을 출력함.

# %% [markdown]
# 인스턴스를 생성할 때 속성 값 할당하려면 다음 예제와 같이 __init__메서드에서 self 다음에 값을 받을 매개변수를 지정

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

# %%
Person()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13912\1977420266.py in <module>
# ----> 1 Person()
#
# TypeError: __init__() missing 2 required positional arguments: 'name' and 'age'

# %%
p1 = Person("홍길동", 22)

# %%
print(p1.name)
# Out:
# 홍길동

# %%
print(p1.age)
# Out:
# 22

# %%
p2 = Person(name="성춘향", age=18)

# %%
print(p2.name)
# Out:
# 성춘향

# %% [markdown]
# ## 4) 클래스 인스턴스 생성할 때 속성 할당하기

# %%
class Person:
    def __init__(self, name, age, address):
        self.hello = "안녕하세요."
        self.name = name
        self.age = age
        self.address = address
    
    def greeting(self):
        print(f'{self.hello} 제 이름은 {self.name} 입니다.')

maria = Person("마리아", 20, "서울시 서초구 반포동")
maria.greeting()

print("이름:", maria.name)
print("나이:", maria.age)
print("주소:", maria.address)
# Out:
# 안녕하세요. 제 이름은 마리아 입니다.
# 이름: 마리아
# 나이: 20
# 주소: 서울시 서초구 반포동

# %%
# 연습 문제
class Person:
    def __init__(self, name, age, address):
        self.name = name
        self.age = age
        self.address = address
    
    def Introduce(self):
        print(f'이름은 무엇인가요?: {self.name}')
        print(f'나이는 무엇인가요?: {self.age}')
        print(f'주소는 무엇인가요?: {self.address}')
        
maria = Person("마리아",20,"서울시 강남구")
james = Person("제임스",21,"서울시 구로구")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13912\1718646195.py in <module>
#      11         input('주소는 무엇인가요?:')
#      12
# ---> 13 maria = Person()
#      14 james = Person()
#
# TypeError: __init__() missing 3 required positional arguments: 'name', 'age', and 'address'

# %%
maria.Introduce()
print(f'이름: {maria.name}\n 나이: {maria.age}\n 주소: {maria.address}')
james.Introduce()
print(f'이름: {james.name}\n 나이: {james.age}\n 주소: {james.address}')
# Out:
# 이름은 무엇인가요?: maria
# 나이은 무엇인가요?: 20
# 주소는 무엇인가요?: 서울시 강남구
# 이름: 마리아
#  나이: 20
#  주소: 서울시 강남구
# 이름은 무엇인가요?: ㄴ
# 나이은 무엇인가요?: ㅇ
# 주소는 무엇인가요?: ㅁ
# 이름: 제임스
#  나이: 21
#  주소: 서울시 구로구

# %%
# 연습 문제
class Person:
    def __init__(self):
        self.name = input('이름은 무엇인가요?:')
        self.age = input('나이은 무엇인가요?:')
        self.address = input('주소는 무엇인가요?:')
    
    def Introduce(self):
        print(f'이름: {self.name}')
        print(f'나이: {self.age}')
        print(f'주소: {self.address}')
        
maria = Person()
james = Person()
# Out:
# 이름은 무엇인가요?: 마리아
# 나이은 무엇인가요?: 20
# 주소는 무엇인가요?: 서울시 강남구
# 이름은 무엇인가요?: 제임스
# 나이은 무엇인가요?: 21
# 주소는 무엇인가요?: 서울시 구로구

# %%
maria.Introduce()
james.Introduce()
# Out:
# 이름: 마리아
# 나이: 20
# 주소: 서울시 강남구
# 이름: 제임스
# 나이: 21
# 주소: 서울시 구로구

# %% [markdown]
# ![image.png](attachment:397d43df-b2aa-4fa2-90cd-a2276ca72932.png)

# %% [markdown]
# ## 5) 비공개 속성 사용
# - 인스턴스.속성 = 값을 통해 새롭게 인스턴스의 속성 값을 변경 못하도록 막고 싶을 때는 비공개 속성을 사용
#
# 사용법은 해당하는 속성 앞에 던디(__)를 붙이면 비공개 속성이 됨

# %%
class ClassExam:
    def __init__(self):
        self.__secret = "비밀입니다." # 비공개 속성

# %%
c1 = ClassExam()
print(c1.__secret)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28348\4181262321.py in <module>
#       1 c1 = ClassExam()
# ----> 2 print(c1.__secret)
#
# AttributeError: 'ClassExam' object has no attribute '__secret'

# %%
class Person:
    def __init__(self, name, age, address, wallet):
        self.name = name
        self.age = age
        self.address = address
        self.__wallet = wallet # 변수 앞에 __를 붙여서 비공개 속성으로 만듦

maria = Person("마리아", 20, "서울시 서초구 반포동", 10000)
maria.__wallet -= 10000 # 클래스 바깥에서 비공개 속성에 접근하면 에러가 발생
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28348\1073520431.py in <module>
#       7
#       8 maria = Person("마리아", 20, "서울시 서초구 반포동", 10000)
# ----> 9 maria.__wallet -= 10000 # 클래스 바깥에서 비공개 속성에 접근하면 에러가 발생
#
# AttributeError: 'Person' object has no attribute '__wallet'

# %%
class Person:
    def __init__(self, name, age, address, wallet):
        self.name = name
        self.age = age
        self.address = address
        self.__wallet = wallet # 변수 앞에 __를 붙여서 비공개 속성으로 만듦

    def pay(self, amount):
        if self.__wallet < amount:
            print("돈이 모자랍니다.")
            return
        self.__wallet -= amount  # 비공개 속성은 클래스 안의 메서드에서만 접근할 수 있음
        print("이제 {0}원 남았네요.".format(self.__wallet))

maria = Person("마리아", 20, "서울시 서초구 반포동", 10000)
maria.pay(3000)
# Out:
# 이제 7000원 남았네요.

# %%
#연습 문제

class Annie:
    def __init__(self):
        self.hp, self.mp, self.ap = map(float,input("체력,마나,AP를 입력하세요.").split(' '))
    def tibbers(self):
        return self.ap * 0.65 + 400

tibber_damage = Annie()
print('티버: 피해량', tibber_damage.tibbers())
# Out:
# 체력,마나,AP를 입력하세요. 1803.68 1184.0 645
# 티버: 피해량 819.25

# %%
# 풀이
class Annie:
    def __init__(self, hp=0, mp=0, ap=0):
        self.hp = hp
        self.mp = mp
        self.ap = ap

    def tibbers(self):
        return self.ap * 0.65 + 400

# %%
a1 = Annie()

# %%
print(a1.hp, a1.mp, a1.ap)
# Out:
# 0 0 0

# %%
# 511.68 334.0 298
hp, mp, ap = map(float,input("애니").split())
# Out:
# 애니 511.68 334.0 298

# %%
a2 = Annie(hp, mp, ap)

# %%
print(a2.hp, a2.mp, a2.ap)
# Out:
# 511.68 334.0 298.0

# %%
a2.tibbers()
# Out:
# 593.7

# %%
import pandas as pd

df_data = pd.read_csv('')
